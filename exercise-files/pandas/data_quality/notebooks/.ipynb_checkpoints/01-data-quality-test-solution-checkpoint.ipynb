# %% [markdown]
# ### Checking your data quality
#
# This notebook looks at various tests that we can run to check the quality of your data. Below are some of the things we will look into:
#
# - Accuracy: How well does a piece of information reflect reality?
# - Completeness: Does it fulfill users’ expectations as to how fully it represents the truth?
# - Timeliness: Is your information available when users need it?
# - Validity: Is information in a specific format or is it in an unusable format?
# - Uniqueness: Is this the only instance in which this information appears in the database?

# %%
import pandas as pd

# %% [markdown]
# Load the data

# %%
election_data  = pd.read_csv("../data/city council (nyccfb.info).csv")

election_data.head()
# Out:
#    UNIQUEID  ELECTION  OFFICECD RECIPID CANCLASS             RECIPNAME  \
# 0  91CB90C2      2023         5     433        P        Schulman, Lynn
# 1  FFACDF77      2023         5    1159        P    Narcisse, Mercedes
# 2  BDEB84A7      2023         5    1984        P   Velazquez, Marjorie
# 3  69252E17      2023         5    2756        P         Salaam, Yusef
# 4  D3C8E6EE      2023         5    2349        P  De La Rosa, Carmen N
#
#   COMMITTEE  FILING SCHEDULE  PAGENO  ...  INTEMPSTNM INTEMPCITY INTEMPST  \
# 0         L       6      ABC     NaN  ...         NaN        NaN      NaN
# 1         K       6      ABC     NaN  ...         NaN        NaN      NaN
# 2         K       7      ABC     NaN  ...         NaN        NaN      NaN
# 3         H      10      ABC     NaN  ...         NaN        NaN      NaN
# 4         J       6      ABC     NaN  ...         NaN        NaN      NaN
#
#   INTOCCUPA PURPOSECD EXEMPTCD  ADJTYPECD  RR_IND  SEG_IND INT_C_CODE
# 0       NaN       NaN      NaN        NaN       N        N        NaN
# 1       NaN       NaN      NaN        NaN       N        N        NaN
# 2       NaN       NaN      NaN        NaN       N        N        NaN
# 3       NaN       NaN      NaN        NaN       N        N        NaN
# 4       NaN       NaN      NaN        NaN       N        N        NaN
#
# [5 rows x 53 columns]

# %% [markdown]
# ##### Accuracy
#
# We will check on some of the values in the `city` column using the `value_counts()` function and by sorting the list alphabetically.

# %%
city_tallies = election_data["CITY"].value_counts()

city_tallies.head()
# Out:
# CITY
# New York         669
# Brooklyn         246
# Staten Island     65
# Flushing          59
# Jamaica           52
# Name: count, dtype: int64

# %%
city_tallies.reset_index().sort_values(by="CITY")
# Out:
#                CITY  count
# 39          ASTORIA      2
# 33  Addisleigh Park      3
# 8           Astoria     25
# 5     BOWLING GREEN     43
# 69         BROOKLYN      1
# ..              ...    ...
# 60     far rockaway      1
# 51         new york      1
# 45          newyork      2
# 37    staten island      3
# 62       whitestone      1
#
# [85 rows x 2 columns]

# %% [markdown]
# #### Completeness
#
# Oftentimes you want to see how many `null values` there are.

# %%
## this line of code will print the rows where the value for "UNIQUEID" is a null value. 
election_data[election_data["UNIQUEID"].isna()]
# Out:
# Empty DataFrame
# Columns: [UNIQUEID, ELECTION, OFFICECD, RECIPID, CANCLASS, RECIPNAME, COMMITTEE, FILING, SCHEDULE, PAGENO, SEQUENCENO, REFNO, DATE, REFUNDDATE, NAME, C_CODE, STRNO, STRNAME, APARTMENT, BOROUGHCD, CITY, STATE, ZIP, OCCUPATION, EMPNAME, EMPSTRNO, EMPSTRNAME, EMPCITY, EMPSTATE, AMNT, MATCHAMNT, PREVAMNT, PAY_METHOD, INTERMNO, INTERMNAME, INTSTRNO, INTSTRNM, INTAPTNO, INTCITY, INTST, INTZIP, INTEMPNAME, INTEMPSTNO, INTEMPSTNM, INTEMPCITY, INTEMPST, INTOCCUPA, PURPOSECD, EXEMPTCD, ADJTYPECD, RR_IND, SEG_IND, INT_C_CODE]
# Index: []
#
# [0 rows x 53 columns]

# %%
## this line of code will print the rows where the value for "OCCUPATION" is a null value. 

election_data[election_data["OCCUPATION"].isna()]
# Out:
#       UNIQUEID  ELECTION  OFFICECD RECIPID CANCLASS             RECIPNAME  \
# 0     91CB90C2      2023         5     433        P        Schulman, Lynn
# 1     FFACDF77      2023         5    1159        P    Narcisse, Mercedes
# 2     BDEB84A7      2023         5    1984        P   Velazquez, Marjorie
# 3     69252E17      2023         5    2756        P         Salaam, Yusef
# 4     D3C8E6EE      2023         5    2349        P  De La Rosa, Carmen N
# ...        ...       ...       ...     ...      ...                   ...
# 1401  84F3BC1F      2023         5    2063       NP       Adams, Adrienne
# 1423  CFCE5684      2023         5    2343        P           Ung, Sandra
# 1426  8DD1C23F      2023         5    1529        P          Menin, Julie
# 1430  8D55B131      2023         5     399        P          Brewer, Gale
# 1455  2EFF1919      2023         5    2206        P      Krishnan, Shekar
#
#      COMMITTEE  FILING SCHEDULE  PAGENO  ...        INTEMPSTNM INTEMPCITY  \
# 0            L       6      ABC     NaN  ...               NaN        NaN
# 1            K       6      ABC     NaN  ...               NaN        NaN
# 2            K       7      ABC     NaN  ...               NaN        NaN
# 3            H      10      ABC     NaN  ...               NaN        NaN
# 4            J       6      ABC     NaN  ...               NaN        NaN
# ...        ...     ...      ...     ...  ...               ...        ...
# 1401         L       2      ABC     NaN  ...               NaN        NaN
# 1423         J       2      ABC     NaN  ...  West 56th Street   New York
# 1426         K       9        M     NaN  ...               NaN        NaN
# 1430         Q       9        M     NaN  ...               NaN        NaN
# 1455         J       9        M     NaN  ...               NaN        NaN
#
#      INTEMPST INTOCCUPA PURPOSECD EXEMPTCD  ADJTYPECD  RR_IND  SEG_IND  \
# 0         NaN       NaN       NaN      NaN        NaN       N        N
# 1         NaN       NaN       NaN      NaN        NaN       N        N
# 2         NaN       NaN       NaN      NaN        NaN       N        N
# 3         NaN       NaN       NaN      NaN        NaN       N        N
# 4         NaN       NaN       NaN      NaN        NaN       N        N
# ...       ...       ...       ...      ...        ...     ...      ...
# 1401      NaN       NaN       NaN      NaN        NaN       N        N
# 1423       NY  Attorney       NaN      NaN        NaN       N        N
# 1426      NaN       NaN       NaN      NaN        2.0       N        N
# 1430      NaN       NaN       NaN      NaN        2.0       N        N
# 1455      NaN       NaN       NaN      NaN        2.0       N        N
#
#      INT_C_CODE
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# ...         ...
# 1401        NaN
# 1423        IND
# 1426        NaN
# 1430        NaN
# 1455        NaN
#
# [497 rows x 53 columns]

# %% [markdown]
# #### Timeliness
#
# Here we will first format the date column to be interpreted as a `datetime` and then we will find some characteristics of that column by using the `.describe()` function.

# %%
election_data["DATE"].dtype
# Out:
# dtype('<M8[ns]')

# %%
election_data["DATE"] = election_data["DATE"].astype("datetime64[ns]")

# %%
election_data["DATE"].describe()
# Out:
# count                             1460
# mean     2023-03-04 16:54:54.246575616
# min                2021-11-13 00:00:00
# 25%                2022-12-13 00:00:00
# 50%                2023-03-05 12:00:00
# 75%                2023-06-23 00:00:00
# max                2023-12-08 00:00:00
# Name: DATE, dtype: object

# %% [markdown]
# ##### Validity
# In this next cell we look at the validity of the data in the zip code column

# %%
election_data["ZIP"] =election_data["ZIP"].astype("str")

# %%
#this line will create a column that measures the length of the value in the zipcode column
election_data["zip_len"] = election_data["ZIP"].apply(lambda x: len(x))

election_data.head()
# Out:
#    UNIQUEID  ELECTION  OFFICECD RECIPID CANCLASS             RECIPNAME  \
# 0  91CB90C2      2023         5     433        P        Schulman, Lynn
# 1  FFACDF77      2023         5    1159        P    Narcisse, Mercedes
# 2  BDEB84A7      2023         5    1984        P   Velazquez, Marjorie
# 3  69252E17      2023         5    2756        P         Salaam, Yusef
# 4  D3C8E6EE      2023         5    2349        P  De La Rosa, Carmen N
#
#   COMMITTEE  FILING SCHEDULE  PAGENO  ...  INTEMPCITY INTEMPST INTOCCUPA  \
# 0         L       6      ABC     NaN  ...         NaN      NaN       NaN
# 1         K       6      ABC     NaN  ...         NaN      NaN       NaN
# 2         K       7      ABC     NaN  ...         NaN      NaN       NaN
# 3         H      10      ABC     NaN  ...         NaN      NaN       NaN
# 4         J       6      ABC     NaN  ...         NaN      NaN       NaN
#
#   PURPOSECD EXEMPTCD ADJTYPECD  RR_IND  SEG_IND  INT_C_CODE zip_len
# 0       NaN      NaN       NaN       N        N         NaN       5
# 1       NaN      NaN       NaN       N        N         NaN       5
# 2       NaN      NaN       NaN       N        N         NaN       5
# 3       NaN      NaN       NaN       N        N         NaN       5
# 4       NaN      NaN       NaN       N        N         NaN       5
#
# [5 rows x 54 columns]

# %%
election_data[election_data["zip_len"] <5]
# Out:
#      UNIQUEID  ELECTION  OFFICECD RECIPID CANCLASS          RECIPNAME  \
# 10   57406798      2023         5     380        P  Moya, Francisco P
# 696  F8A17C16      2023         5    1529        P       Menin, Julie
# 906  F953A326      2023         5    1990        P    Brannan, Justin
#
#     COMMITTEE  FILING SCHEDULE  PAGENO  ...  INTEMPCITY INTEMPST INTOCCUPA  \
# 10          M       5      ABC     NaN  ...         NaN      NaN       NaN
# 696         K       2      ABC     NaN  ...         NaN      NaN       NaN
# 906         L       7      ABC     NaN  ...         NaN      NaN       NaN
#
#     PURPOSECD EXEMPTCD ADJTYPECD  RR_IND  SEG_IND  INT_C_CODE zip_len
# 10        NaN      NaN       NaN       N        N         NaN       4
# 696       NaN      NaN       NaN       N        N         NaN       4
# 906       NaN      NaN       NaN       N        N         NaN       3
#
# [3 rows x 54 columns]

# %% [markdown]
# ##### Uniqueness
#
# We will use the `duplicated()` function to see which rows are duplicates'.

# %%
#the line below should show the two rows that are duplicates and follow the
election_data[election_data.duplicated()]
# Out:
#       UNIQUEID  ELECTION  OFFICECD RECIPID CANCLASS      RECIPNAME COMMITTEE  \
# 49    E64E955F      2023         5    2762        P  Chan, Wai Yee         H
# 1325  E64E955F      2023         5    2762        P  Chan, Wai Yee         H
#
#       FILING SCHEDULE  PAGENO  ...  INTEMPCITY INTEMPST INTOCCUPA PURPOSECD  \
# 49         6      ABC     NaN  ...         NaN      NaN       NaN       NaN
# 1325       6      ABC     NaN  ...         NaN      NaN       NaN       NaN
#
#      EXEMPTCD ADJTYPECD  RR_IND  SEG_IND  INT_C_CODE zip_len
# 49        NaN       NaN       N        N         NaN       5
# 1325      NaN       NaN       N        N         NaN       5
#
# [2 rows x 54 columns]
