# %% [markdown]
# ### Load options, Groupby, Lambdas and Functions
#
# This notebook gives you more sophisticated methods of maniputaling your data using lambda functions and more customized functions as well as a way to create more sophisticated ways to summarize your data.

# %%
import pandas as pd

# %% [markdown]
# **NEW:**
# Every function comes with various options you can specify. Below we are looking at assigning data types you can assign to each column

# %%
# %%time
tweets = pd.read_csv(
    '../data/ira_tweets_csv_hashed.csv', 
    dtype = {'tweetid': 'str','retweet_tweetid':'str'}, # <-- here you can specify data as strings, floats or integers,
    parse_dates = ['account_creation_date', 'tweet_time'] # <-- this line makes pandas interpret these columns as dates   
)
# Out:
# CPU times: user 1min 49s, sys: 1min 32s, total: 3min 21s
# Wall time: 5min 59s

# %%
len(tweets)
# Out:
# 9041308

# %%
tweets.dtypes
# Out:
# tweetid                             object
# userid                              object
# user_display_name                   object
# user_screen_name                    object
# user_reported_location              object
# user_profile_description            object
# user_profile_url                    object
# follower_count                       int64
# following_count                      int64
# account_creation_date       datetime64[ns]
# account_language                    object
# tweet_language                      object
# tweet_text                          object
# tweet_time                  datetime64[ns]
# tweet_client_name                   object
# in_reply_to_tweetid                float64
# in_reply_to_userid                  object
# quoted_tweet_tweetid               float64
# is_retweet                            bool
# retweet_userid                      object
# retweet_tweetid                     object
# latitude                           float64
# longitude                          float64
# quote_count                        float64
# reply_count                        float64
# like_count                         float64
# retweet_count                      float64
# hashtags                            object
# urls                                object
# user_mentions                       object
# poll_choices                        object
# dtype: object

# %%
tweets.head().T
# Out:
#                                                                           0  \
# tweetid                                                  877919995476496385
# userid                    249064136b1c5cb00a705316ab73dd9b53785748ab757f...
# user_display_name         249064136b1c5cb00a705316ab73dd9b53785748ab757f...
# user_screen_name          249064136b1c5cb00a705316ab73dd9b53785748ab757f...
# user_reported_location                                       Москва, Россия
# user_profile_description                              Я примерный семьянин!
# user_profile_url                                                        NaN
# follower_count                                                          132
# following_count                                                         120
# account_creation_date                                   2013-12-07 00:00:00
# account_language                                                         ru
# tweet_language                                                           ru
# tweet_text                RT @ruopentwit: ⚡️У НАС НОВОЕ ВИДЕО! Американе...
# tweet_time                                              2017-06-22 16:03:00
# tweet_client_name                                                 TweetDeck
# in_reply_to_tweetid                                                     NaN
# in_reply_to_userid                                                      NaN
# quoted_tweet_tweetid                                                    NaN
# is_retweet                                                             True
# retweet_userid                                                   2572896396
# retweet_tweetid                                          877917212119416832
# latitude                                                                NaN
# longitude                                                               NaN
# quote_count                                                               0
# reply_count                                                               0
# like_count                                                                0
# retweet_count                                                             0
# hashtags                                                                 []
# urls                           [http://ru-open.livejournal.com/374284.html]
# user_mentions                                                  [2572896396]
# poll_choices                                                            NaN
#
#                                                                           1  \
# tweetid                                                  492388766930444288
# userid                    0974d5dbee4ca9bd6c3b46d62a5cbdbd5c0d86e196b624...
# user_display_name         0974d5dbee4ca9bd6c3b46d62a5cbdbd5c0d86e196b624...
# user_screen_name          0974d5dbee4ca9bd6c3b46d62a5cbdbd5c0d86e196b624...
# user_reported_location                                               Россия
# user_profile_description  Телефонист .Изучение истории   Игра в любитель...
# user_profile_url                                                        NaN
# follower_count                                                           74
# following_count                                                           8
# account_creation_date                                   2014-03-15 00:00:00
# account_language                                                         en
# tweet_language                                                           ru
# tweet_text                     Серебром отколоколило http://t.co/Jaa4v4IFpM
# tweet_time                                              2014-07-24 19:20:00
# tweet_client_name                                               generationπ
# in_reply_to_tweetid                                                     NaN
# in_reply_to_userid                                                      NaN
# quoted_tweet_tweetid                                                    NaN
# is_retweet                                                            False
# retweet_userid                                                          NaN
# retweet_tweetid                                                         NaN
# latitude                                                                NaN
# longitude                                                               NaN
# quote_count                                                               0
# reply_count                                                               0
# like_count                                                                0
# retweet_count                                                             0
# hashtags                                                                NaN
# urls                          [http://pyypilg33.livejournal.com/11069.html]
# user_mentions                                                           NaN
# poll_choices                                                            NaN
#
#                                                                           2  \
# tweetid                                                  719455077589721089
# userid                    bda40f262856eee77c48a332e5eb23bc4f1943d600867d...
# user_display_name         bda40f262856eee77c48a332e5eb23bc4f1943d600867d...
# user_screen_name          bda40f262856eee77c48a332e5eb23bc4f1943d600867d...
# user_reported_location                                               Рязань
# user_profile_description               волны так и плещут фиолетовой волной
# user_profile_url                                                        NaN
# follower_count                                                          165
# following_count                                                         454
# account_creation_date                                   2014-04-29 00:00:00
# account_language                                                         en
# tweet_language                                                           bg
# tweet_text                      @kpru С-300 в Иране https://t.co/elnu3qLUW7
# tweet_time                                              2016-04-11 09:20:00
# tweet_client_name                                                 TweetDeck
# in_reply_to_tweetid                                              7.1944e+17
# in_reply_to_userid                                                 40807205
# quoted_tweet_tweetid                                                    NaN
# is_retweet                                                            False
# retweet_userid                                                          NaN
# retweet_tweetid                                                         NaN
# latitude                                                                NaN
# longitude                                                               NaN
# quote_count                                                               0
# reply_count                                                               0
# like_count                                                                0
# retweet_count                                                             0
# hashtags                                                                 []
# urls                          [https://www.youtube.com/watch?v=9GvpImWxTJc]
# user_mentions                                                    [40807205]
# poll_choices                                                            NaN
#
#                                                                           3  \
# tweetid                                                  536179342423105537
# userid                    bda40f262856eee77c48a332e5eb23bc4f1943d600867d...
# user_display_name         bda40f262856eee77c48a332e5eb23bc4f1943d600867d...
# user_screen_name          bda40f262856eee77c48a332e5eb23bc4f1943d600867d...
# user_reported_location                                               Рязань
# user_profile_description               волны так и плещут фиолетовой волной
# user_profile_url                                                        NaN
# follower_count                                                          165
# following_count                                                         454
# account_creation_date                                   2014-04-29 00:00:00
# account_language                                                         en
# tweet_language                                                           ru
# tweet_text                Предлагаю судить их за поддержку нацизма, т.к....
# tweet_time                                              2014-11-22 15:28:00
# tweet_client_name                                        Twitter Web Client
# in_reply_to_tweetid                                                     NaN
# in_reply_to_userid                                                      NaN
# quoted_tweet_tweetid                                                    NaN
# is_retweet                                                            False
# retweet_userid                                                          NaN
# retweet_tweetid                                                         NaN
# latitude                                                                NaN
# longitude                                                               NaN
# quote_count                                                               0
# reply_count                                                               0
# like_count                                                                0
# retweet_count                                                             0
# hashtags                                                         [STOPNazi]
# urls                                                                    NaN
# user_mentions                                                           NaN
# poll_choices                                                            NaN
#
#                                                                           4
# tweetid                                                  841410788409630720
# userid                    a53ed619f1dea6015c7c878bf744b0eefe8f7272dccf34...
# user_display_name         a53ed619f1dea6015c7c878bf744b0eefe8f7272dccf34...
# user_screen_name          a53ed619f1dea6015c7c878bf744b0eefe8f7272dccf34...
# user_reported_location                                                  NaN
# user_profile_description                 Отвечаю на любой #ВопросПрезиденту
# user_profile_url                                     http://t.co/3CVqbMQFbf
# follower_count                                                         4430
# following_count                                                        4413
# account_creation_date                                   2012-02-25 00:00:00
# account_language                                                         ru
# tweet_language                                                           bg
# tweet_text                Предостережение американского дипломата https:...
# tweet_time                                              2017-03-13 22:08:00
# tweet_client_name                                        Twitter Web Client
# in_reply_to_tweetid                                                     NaN
# in_reply_to_userid                                                      NaN
# quoted_tweet_tweetid                                                    NaN
# is_retweet                                                            False
# retweet_userid                                                          NaN
# retweet_tweetid                                                         NaN
# latitude                                                                NaN
# longitude                                                               NaN
# quote_count                                                               0
# reply_count                                                               0
# like_count                                                                3
# retweet_count                                                             4
# hashtags                                                                 []
# urls                                                [https://goo.gl/fBp94X]
# user_mentions                                                           NaN
# poll_choices                                                            NaN

# %%
# %%time
tweets_2016_2018 = tweets[
    tweets['tweet_time'].dt.year > 2015
]
# Out:
# CPU times: user 3.48 s, sys: 17.9 s, total: 21.3 s
# Wall time: 48 s

# %%
print(len(tweets_2016_2018))
tweets_2016_2018.head()
# Out:
# 3179248
#                tweetid                                             userid  \
# 0   877919995476496385  249064136b1c5cb00a705316ab73dd9b53785748ab757f...
# 2   719455077589721089  bda40f262856eee77c48a332e5eb23bc4f1943d600867d...
# 4   841410788409630720  a53ed619f1dea6015c7c878bf744b0eefe8f7272dccf34...
# 5   834365760776630272  a53ed619f1dea6015c7c878bf744b0eefe8f7272dccf34...
# 13  701008777001107457  f9dded769bb2275fc6531c1b4d10cf05272c48806fbd73...
#
#                                     user_display_name  \
# 0   249064136b1c5cb00a705316ab73dd9b53785748ab757f...
# 2   bda40f262856eee77c48a332e5eb23bc4f1943d600867d...
# 4   a53ed619f1dea6015c7c878bf744b0eefe8f7272dccf34...
# 5   a53ed619f1dea6015c7c878bf744b0eefe8f7272dccf34...
# 13  f9dded769bb2275fc6531c1b4d10cf05272c48806fbd73...
#
#                                      user_screen_name user_reported_location  \
# 0   249064136b1c5cb00a705316ab73dd9b53785748ab757f...         Москва, Россия
# 2   bda40f262856eee77c48a332e5eb23bc4f1943d600867d...                 Рязань
# 4   a53ed619f1dea6015c7c878bf744b0eefe8f7272dccf34...                    NaN
# 5   a53ed619f1dea6015c7c878bf744b0eefe8f7272dccf34...                    NaN
# 13  f9dded769bb2275fc6531c1b4d10cf05272c48806fbd73...                    NaN
#
#                 user_profile_description        user_profile_url  \
# 0                  Я примерный семьянин!                     NaN
# 2   волны так и плещут фиолетовой волной                     NaN
# 4     Отвечаю на любой #ВопросПрезиденту  http://t.co/3CVqbMQFbf
# 5     Отвечаю на любой #ВопросПрезиденту  http://t.co/3CVqbMQFbf
# 13                                   NaN                     NaN
#
#     follower_count  following_count account_creation_date     ...       \
# 0              132              120            2013-12-07     ...
# 2              165              454            2014-04-29     ...
# 4             4430             4413            2012-02-25     ...
# 5             4430             4413            2012-02-25     ...
# 13              86              279            2015-09-28     ...
#
#    latitude longitude quote_count reply_count like_count  retweet_count  \
# 0       NaN       NaN         0.0         0.0        0.0            0.0
# 2       NaN       NaN         0.0         0.0        0.0            0.0
# 4       NaN       NaN         0.0         0.0        3.0            4.0
# 5       NaN       NaN         0.0         0.0        3.0            5.0
# 13      NaN       NaN         0.0         0.0        0.0            0.0
#
#    hashtags                                           urls  user_mentions  \
# 0        []   [http://ru-open.livejournal.com/374284.html]   [2572896396]
# 2        []  [https://www.youtube.com/watch?v=9GvpImWxTJc]     [40807205]
# 4        []                        [https://goo.gl/fBp94X]            NaN
# 5        []                        [https://goo.gl/9w5hso]            NaN
# 13       []                        [http://bit.ly/1PMZqPI]            NaN
#
#    poll_choices
# 0           NaN
# 2           NaN
# 4           NaN
# 5           NaN
# 13          NaN
#
# [5 rows x 31 columns]

# %%
grouped_tweets = tweets_2016_2018.groupby(['account_language','user_reported_location'])['tweetid'].count()

# %%
grouped_tweets
# Out:
# account_language  user_reported_location
# ar                Az-Zarqa                              1
#                   Egypt                                 1
#                   United States                       193
#                   الدمام                                7
#                   سوريا                                12
#                   سورية                                 5
# de                Berlin, Deutschland               28451
#                   Bremen, Deutschland                 228
#                   Deutschland                         230
#                   Dresden, Sachsen                   7920
#                   Düsseldorf, Deutschland             306
#                   Erfurt, Deutschland                4053
#                   Frankfurt am Main, Deutschland     5099
#                   Frankfurt am Main, Hessen           137
#                   Germany                            2524
#                   Hamburg, Deutschland              14634
#                   Hessen, Deutschland                3254
#                   Kiel, Schleswig-Holstein            214
#                   Köln, Deutschland                  5648
#                   Magdeburg, Deutschland              201
#                   München, Bayern                    6167
#                   Rostock, Deutschland                210
#                   Saarbrücken, Deutschland            183
#                   Stuttgart, Deutschland             5107
# en                2148                                 23
#                   AL                                 3609
#                   AMERICA                               5
#                   ATL                                2991
#                   ATL, GA                              73
#                   Alaska                             2369
#                                                     ...
# ru                Сочи                               2943
#                   Сочи                                  2
#                   Сочи, Россия                         23
#                   Спб                                   4
#                   Сраратов                            798
#                   Стамбул                             594
#                   Стокгольм                           100
#                   Таллин                              133
#                   Тверское подворье                   208
#                   Тверь                               112
#                   Томск                                68
#                   Тула                                 41
#                   Тула, Россия                       5337
#                   Тула, Тульская область            23614
#                   Украина                               9
#                   Хабаровск                            22
#                   Хабаровск, Россия                    35
#                   Челябинск                          1045
#                   Чеченская республика, Россия        130
#                   Чита                               3499
#                   Я везде                            1979
#                   Ярославль                             1
#                   Ярославль                           115
#                   Ярославль, Россия                  2477
#                   баку                                469
#                   мск                                  39
#                   новосибирск                           7
#                   питер                               119
#                   сжигай толерантный рай,слышишь      321
#                   ♠Питер♠                             156
# Name: tweetid, Length: 398, dtype: int64

# %%
grouped_tweets.reset_index()
# Out:
#     account_language          user_reported_location  tweetid
# 0                 ar                        Az-Zarqa        1
# 1                 ar                           Egypt        1
# 2                 ar                   United States      193
# 3                 ar                          الدمام        7
# 4                 ar                           سوريا       12
# 5                 ar                           سورية        5
# 6                 de             Berlin, Deutschland    28451
# 7                 de             Bremen, Deutschland      228
# 8                 de                     Deutschland      230
# 9                 de                Dresden, Sachsen     7920
# 10                de         Düsseldorf, Deutschland      306
# 11                de             Erfurt, Deutschland     4053
# 12                de  Frankfurt am Main, Deutschland     5099
# 13                de       Frankfurt am Main, Hessen      137
# 14                de                         Germany     2524
# 15                de            Hamburg, Deutschland    14634
# 16                de             Hessen, Deutschland     3254
# 17                de        Kiel, Schleswig-Holstein      214
# 18                de               Köln, Deutschland     5648
# 19                de          Magdeburg, Deutschland      201
# 20                de                 München, Bayern     6167
# 21                de            Rostock, Deutschland      210
# 22                de        Saarbrücken, Deutschland      183
# 23                de          Stuttgart, Deutschland     5107
# 24                en                            2148       23
# 25                en                              AL     3609
# 26                en                         AMERICA        5
# 27                en                             ATL     2991
# 28                en                         ATL, GA       73
# 29                en                          Alaska     2369
# ..               ...                             ...      ...
# 368               ru                            Сочи     2943
# 369               ru                           Сочи         2
# 370               ru                    Сочи, Россия       23
# 371               ru                             Спб        4
# 372               ru                        Сраратов      798
# 373               ru                         Стамбул      594
# 374               ru                       Стокгольм      100
# 375               ru                         Таллин       133
# 376               ru               Тверское подворье      208
# 377               ru                           Тверь      112
# 378               ru                           Томск       68
# 379               ru                            Тула       41
# 380               ru                    Тула, Россия     5337
# 381               ru          Тула, Тульская область    23614
# 382               ru                         Украина        9
# 383               ru                       Хабаровск       22
# 384               ru               Хабаровск, Россия       35
# 385               ru                       Челябинск     1045
# 386               ru    Чеченская республика, Россия      130
# 387               ru                            Чита     3499
# 388               ru                         Я везде     1979
# 389               ru                       Ярославль        1
# 390               ru                      Ярославль       115
# 391               ru               Ярославль, Россия     2477
# 392               ru                            баку      469
# 393               ru                             мск       39
# 394               ru                     новосибирск        7
# 395               ru                           питер      119
# 396               ru  сжигай толерантный рай,слышишь      321
# 397               ru                         ♠Питер♠      156
#
# [398 rows x 3 columns]

# %%
grouped_tweets.reset_index().sort_values(by = 'tweetid', ascending=False)
# Out:
#     account_language        user_reported_location  tweetid
# 191               en                           USA   476040
# 252               es                Estados Unidos   285012
# 195               en                 United States   246566
# 360               ru       Санкт-Петербург, Россия    65393
# 326               ru                        Москва    62175
# 351               ru                       Россия     55356
# 61                en                   Chicago, IL    43390
# 329               ru                Москва, Россия    40486
# 36                en                       Atlanta    29047
# 6                 de           Berlin, Deutschland    28451
# 104               en               Kansas City, MO    26529
# 188               en                    Texas, USA    25610
# 177               en             San Francisco, CA    25193
# 359               ru               Санкт-Петербург    24017
# 148               en                  New York, NY    23701
# 381               ru        Тула, Тульская область    23614
# 112               en               Los Angeles, CA    21180
# 180               en                       StLouis    20829
# 37                en                   Atlanta, GA    20561
# 164               en                Pittsburgh, US    20545
# 190               en                            US    19901
# 179               en                  St Louis, MO    19542
# 350               ru                        Россия    17064
# 162               en              Philadelphia, PA    17026
# 41                en                 Baltimore, MD    17013
# 63                en        City of Cleveland, USA    14751
# 15                de          Hamburg, Deutschland    14634
# 327               ru        Москва (СССР - Россия)    14583
# 42                en               Baton Rouge, LA    14580
# 178               en                   Seattle, WA    14292
# ..               ...                           ...      ...
# 26                en                       AMERICA        5
# 266               ru                   Krasnoyarsk        5
# 80                en                         Egypt        4
# 371               ru                           Спб        4
# 261               ru                   Atlanta, GA        3
# 122               en                    Miami, USA        3
# 369               ru                         Сочи         2
# 114               en                     Macon, GA        2
# 136               en                            NJ        2
# 124               en    Millville village, OH, USA        2
# 43                en                        Beirut        2
# 203               en                 Zarqa, Jordan        1
# 1                 ar                         Egypt        1
# 389               ru                     Ярославль        1
# 228               en                     Петербург        1
# 245               en                        العراق        1
# 168               en                  Rhode island        1
# 185               en                        THE US        1
# 31                en                        Aleppo        1
# 271               ru  Oliva Pizza & Pasta // Amman        1
# 70                en                        Dallas        1
# 44                en                    Birmingham        1
# 47                en                    Boston, MA        1
# 116               en               Manama, Bahrain        1
# 73                en                      Damascus        1
# 52                en                            CA        1
# 56                en                            Ch        1
# 308               ru                     Запорожье        1
# 71                en                    Dallas, TX        1
# 0                 ar                      Az-Zarqa        1
#
# [398 rows x 3 columns]

# %% [markdown]
# ### Lambdas
# Lambdas are functions you can use to manipulate your columns. Think of them as mini-functions. You use them in conjunction with the `.apply()` function.

# %%
num_tweets_per_country_language = grouped_tweets.reset_index().sort_values(by = 'tweetid', ascending=False)

# %%
num_tweets_per_country_language['tweetid'].apply(lambda x: x/len(tweets_2016_2018) *100)
# Out:
# 191    14.973352
# 252     8.964761
# 195     7.755482
# 360     2.056870
# 326     1.955651
# 351     1.741166
# 61      1.364788
# 329     1.273446
# 36      0.913644
# 6       0.894897
# 104     0.834443
# 188     0.805536
# 177     0.792420
# 359     0.755430
# 148     0.745491
# 381     0.742754
# 112     0.666195
# 180     0.655155
# 37      0.646725
# 164     0.646222
# 190     0.625966
# 179     0.614674
# 350     0.536731
# 162     0.535535
# 41      0.535127
# 63      0.463978
# 15      0.460298
# 327     0.458693
# 42      0.458599
# 178     0.449540
#          ...
# 26      0.000157
# 266     0.000157
# 80      0.000126
# 371     0.000126
# 261     0.000094
# 122     0.000094
# 369     0.000063
# 114     0.000063
# 136     0.000063
# 124     0.000063
# 43      0.000063
# 203     0.000031
# 1       0.000031
# 389     0.000031
# 228     0.000031
# 245     0.000031
# 168     0.000031
# 185     0.000031
# 31      0.000031
# 271     0.000031
# 70      0.000031
# 44      0.000031
# 47      0.000031
# 116     0.000031
# 73      0.000031
# 52      0.000031
# 56      0.000031
# 308     0.000031
# 71      0.000031
# 0       0.000031
# Name: tweetid, Length: 398, dtype: float64

# %%
num_tweets_per_country_language['percent_of_all_tweets'] = num_tweets_per_country_language['tweetid'].apply(lambda x: (x/len(tweets_2016_2018)) *100)

# %%
num_tweets_per_country_language.head()
# Out:
#     account_language   user_reported_location  tweetid  percent_of_all_tweets
# 191               en                      USA   476040              14.973352
# 252               es           Estados Unidos   285012               8.964761
# 195               en            United States   246566               7.755482
# 360               ru  Санкт-Петербург, Россия    65393               2.056870
# 326               ru                   Москва    62175               1.955651

# %% [markdown]
# Here's how you do the same thing with a function:

# %%
def calculate_pct(x):
    return (x/len(tweets_2016_2018)) * 100

# %%
num_tweets_per_country_language['percent_of_all_tweets2'] = num_tweets_per_country_language['tweetid'].apply(calculate_pct)

# %%
num_tweets_per_country_language.head()
# Out:
#     account_language   user_reported_location  tweetid  percent_of_all_tweets  \
# 191               en                      USA   476040              14.973352
# 252               es           Estados Unidos   285012               8.964761
# 195               en            United States   246566               7.755482
# 360               ru  Санкт-Петербург, Россия    65393               2.056870
# 326               ru                   Москва    62175               1.955651
#
#      percent_of_all_tweets2
# 191               14.973352
# 252                8.964761
# 195                7.755482
# 360                2.056870
# 326                1.955651
