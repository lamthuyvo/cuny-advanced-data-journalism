# %% [markdown]
# ### Modifying and merging data sets
# One of the most powerful ways to use data sets is by merging them. This notebook goes over the following things:
# - preparing data for merging by cleaning it
# - concatenating data sets
# - merging data based on a common column

# %%
import pandas as pd

# %% [markdown]
# ### Concatenation
# Concatenation is the process of combining data sets that all have the same column headers. Think of it as a way to combinging thousands of rows of data.

# %%
charges_01 = pd.read_csv('../data/SH Charge Receipts - 01.csv')
charges_02 = pd.read_csv('../data/SH Charge Receipts - 02.csv')
charges_03 = pd.read_csv('../data/SH Charge Receipts - 03.csv')

# %%
print(len(charges_01), len(charges_02), len(charges_03))
# Out:
# 64999 64999 40024

# %%
charges_01.head()
# Out:
#   CHARGE_FILING_DATE  CP_SEX                CP_NATIONAL_ORIGIN        CP_DOB  \
# 0       Oct/01/1995   Female  Other National Origin - Obsolete  Oct/21/1969
# 1       Oct/02/1995   Female  Other National Origin - Obsolete  Jan/01/2001
# 2       Oct/02/1995   Female  Other National Origin - Obsolete  Jul/30/1960
# 3       Oct/02/1995     Male  Other National Origin - Obsolete  Jun/02/1957
# 4       Oct/02/1995   Female  Other National Origin - Obsolete  Apr/15/1959
#
#   HISPANIC_CP CP_RACE_STRING  R_NAICS_CODE  \
# 0         NaN              B      311612.0
# 1         NaN              O      541990.0
# 2         NaN              W      722110.0
# 3         NaN              B      422990.0
# 4         NaN              W      523999.0
#
#                                  R_NAICS_DESCRIPTION R_NUMBER_OF_EMPLOYEES  \
# 0                      Meat Processed from Carcasses   201 - 500 Employees
# 1  All Other Professional, Scientific, and Techni...    15 - 100 Employees
# 2                           Full-Service Restaurants    15 - 100 Employees
# 3   Other Miscellaneous Nondurable Goods Wholesalers    15 - 100 Employees
# 4      Miscellaneous Financial Investment Activities        501+ Employees
#
#              R_TYPE
# 0  Private Employer
# 1  Private Employer
# 2  Private Employer
# 3  Private Employer
# 4  Private Employer

# %%
all_charges = pd.concat([ charges_01, charges_02, charges_03])
print(len(all_charges))
# Out:
# 170022

# %%
all_charges.head()
# Out:
#   CHARGE_FILING_DATE  CP_SEX                CP_NATIONAL_ORIGIN        CP_DOB  \
# 0       Oct/01/1995   Female  Other National Origin - Obsolete  Oct/21/1969
# 1       Oct/02/1995   Female  Other National Origin - Obsolete  Jan/01/2001
# 2       Oct/02/1995   Female  Other National Origin - Obsolete  Jul/30/1960
# 3       Oct/02/1995     Male  Other National Origin - Obsolete  Jun/02/1957
# 4       Oct/02/1995   Female  Other National Origin - Obsolete  Apr/15/1959
#
#   HISPANIC_CP CP_RACE_STRING  R_NAICS_CODE  \
# 0         NaN              B      311612.0
# 1         NaN              O      541990.0
# 2         NaN              W      722110.0
# 3         NaN              B      422990.0
# 4         NaN              W      523999.0
#
#                                  R_NAICS_DESCRIPTION R_NUMBER_OF_EMPLOYEES  \
# 0                      Meat Processed from Carcasses   201 - 500 Employees
# 1  All Other Professional, Scientific, and Techni...    15 - 100 Employees
# 2                           Full-Service Restaurants    15 - 100 Employees
# 3   Other Miscellaneous Nondurable Goods Wholesalers    15 - 100 Employees
# 4      Miscellaneous Financial Investment Activities        501+ Employees
#
#              R_TYPE
# 0  Private Employer
# 1  Private Employer
# 2  Private Employer
# 3  Private Employer
# 4  Private Employer

# %%
all_charges.dtypes
# Out:
# CHARGE_FILING_DATE        object
# CP_SEX                    object
# CP_NATIONAL_ORIGIN        object
# CP_DOB                    object
# HISPANIC_CP               object
# CP_RACE_STRING            object
# R_NAICS_CODE             float64
# R_NAICS_DESCRIPTION       object
# R_NUMBER_OF_EMPLOYEES     object
# R_TYPE                    object
# dtype: object

# %% [markdown]
# ### Finding values that can facilitate merging
# - load the data set you want to merge with your other data set
# - modify your original data set to make sure you have a common column to merge on
# - merge your data sets!

# %%
# Read csv of economic data
economic_data = pd.read_csv('../data/bls_sector_metrics.csv')
economic_data.head()
# Out:
#    naics_sector  naics_sector_rollup  naics_supersector  \
# 0            11                   11                NaN
# 1            21                   21               10.0
# 2            22                   22               40.0
# 3            23                   23               20.0
# 4            31                   31               30.0
#
#                                naics_sector_name  avg_hrly_earnings  \
# 0     Agriculture, Forestry, Fishing and Hunting              14.33
# 1  Mining, Quarrying, and Oil and Gas Extraction              32.95
# 2                                      Utilities              38.35
# 3                                   Construction              25.30
# 4                                  Manufacturing              24.39
#
#    total_employment  women_percentage               source
# 0            416.60          0.224000              oes,cps
# 1            610.20          0.151754                  ces
# 2            555.90          0.232776                  ces
# 3           6687.38          0.125019  oes,ces_supersector
# 4          12337.52          0.274534  oes,ces_supersector

# %%
len(economic_data)
# Out:
# 24

# %%
economic_data.dtypes
# Out:
# naics_sector             int64
# naics_sector_rollup      int64
# naics_supersector      float64
# naics_sector_name       object
# avg_hrly_earnings      float64
# total_employment       float64
# women_percentage       float64
# source                  object
# dtype: object

# %%
economic_data['naics_sector'] = economic_data['naics_sector'].astype(str)

# %%
economic_data.dtypes
# Out:
# naics_sector            object
# naics_sector_rollup      int64
# naics_supersector      float64
# naics_sector_name       object
# avg_hrly_earnings      float64
# total_employment       float64
# women_percentage       float64
# source                  object
# dtype: object

# %%
all_charges['R_NAICS_CODE'] = all_charges['R_NAICS_CODE'].astype(str)

# %%
all_charges.dtypes
# Out:
# CHARGE_FILING_DATE       object
# CP_SEX                   object
# CP_NATIONAL_ORIGIN       object
# CP_DOB                   object
# HISPANIC_CP              object
# CP_RACE_STRING           object
# R_NAICS_CODE             object
# R_NAICS_DESCRIPTION      object
# R_NUMBER_OF_EMPLOYEES    object
# R_TYPE                   object
# dtype: object

# %%
all_charges['naics_sector'] = all_charges['R_NAICS_CODE'].apply(lambda x: x[:2])

# %%
all_charges.head()
# Out:
#   CHARGE_FILING_DATE  CP_SEX                CP_NATIONAL_ORIGIN        CP_DOB  \
# 0       Oct/01/1995   Female  Other National Origin - Obsolete  Oct/21/1969
# 1       Oct/02/1995   Female  Other National Origin - Obsolete  Jan/01/2001
# 2       Oct/02/1995   Female  Other National Origin - Obsolete  Jul/30/1960
# 3       Oct/02/1995     Male  Other National Origin - Obsolete  Jun/02/1957
# 4       Oct/02/1995   Female  Other National Origin - Obsolete  Apr/15/1959
#
#   HISPANIC_CP CP_RACE_STRING R_NAICS_CODE  \
# 0         NaN              B     311612.0
# 1         NaN              O     541990.0
# 2         NaN              W     722110.0
# 3         NaN              B     422990.0
# 4         NaN              W     523999.0
#
#                                  R_NAICS_DESCRIPTION R_NUMBER_OF_EMPLOYEES  \
# 0                      Meat Processed from Carcasses   201 - 500 Employees
# 1  All Other Professional, Scientific, and Techni...    15 - 100 Employees
# 2                           Full-Service Restaurants    15 - 100 Employees
# 3   Other Miscellaneous Nondurable Goods Wholesalers    15 - 100 Employees
# 4      Miscellaneous Financial Investment Activities        501+ Employees
#
#              R_TYPE naics_sector
# 0  Private Employer           31
# 1  Private Employer           54
# 2  Private Employer           72
# 3  Private Employer           42
# 4  Private Employer           52

# %%
all_charges_economic_data = pd.merge(
    all_charges,
    economic_data,
    on='naics_sector',
    how = 'inner'

)

# %%
all_charges_economic_data.head()
# Out:
#   CHARGE_FILING_DATE  CP_SEX                CP_NATIONAL_ORIGIN        CP_DOB  \
# 0       Oct/01/1995   Female  Other National Origin - Obsolete  Oct/21/1969
# 1       Oct/02/1995   Female  Other National Origin - Obsolete  Dec/20/1946
# 2       Oct/06/1995   Female  Other National Origin - Obsolete  Aug/31/1974
# 3       Oct/11/1995   Female               Hispanic - Obsolete  Aug/08/1963
# 4       Oct/16/1995   Female  Other National Origin - Obsolete  Jan/01/1901
#
#   HISPANIC_CP CP_RACE_STRING R_NAICS_CODE  \
# 0         NaN              B     311612.0
# 1         NaN              W     314999.0
# 2         NaN              B     311612.0
# 3         NaN              W     311999.0
# 4         NaN              O     316219.0
#
#                              R_NAICS_DESCRIPTION R_NUMBER_OF_EMPLOYEES  \
# 0                  Meat Processed from Carcasses   201 - 500 Employees
# 1  All Other Miscellaneous Textile Product Mills    15 - 100 Employees
# 2                  Meat Processed from Carcasses        501+ Employees
# 3     All Other Miscellaneous Food Manufacturing    15 - 100 Employees
# 4                   Other Footwear Manufacturing        501+ Employees
#
#              R_TYPE naics_sector  naics_sector_rollup  naics_supersector  \
# 0  Private Employer           31                   31               30.0
# 1  Private Employer           31                   31               30.0
# 2  Private Employer           31                   31               30.0
# 3  Private Employer           31                   31               30.0
# 4  Private Employer           31                   31               30.0
#
#   naics_sector_name  avg_hrly_earnings  total_employment  women_percentage  \
# 0     Manufacturing              24.39          12337.52          0.274534
# 1     Manufacturing              24.39          12337.52          0.274534
# 2     Manufacturing              24.39          12337.52          0.274534
# 3     Manufacturing              24.39          12337.52          0.274534
# 4     Manufacturing              24.39          12337.52          0.274534
#
#                 source
# 0  oes,ces_supersector
# 1  oes,ces_supersector
# 2  oes,ces_supersector
# 3  oes,ces_supersector
# 4  oes,ces_supersector
