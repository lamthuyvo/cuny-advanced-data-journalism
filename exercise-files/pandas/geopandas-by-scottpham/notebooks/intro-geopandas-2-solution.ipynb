# %% [markdown]
# **Mapping unemployment data by county**

# %% [markdown]
# Import your libraries

# %%
import geopandas as gpd
import pandas as pd

# %% [markdown]
# Remember the magic command for every notebook

# %%
# %matplotlib inline

# %% [markdown]
# Load up the unemployment data

# %%
df = pd.read_csv(
    "../data/unemployment_2018.csv",
    dtype = {
        "state_fips": "object",
        "county_fips": "object",
        "combined_fips": "str"
    }
)

df.head()
# Out:
#   state_fips county_fips combined_fips                name  percent_unemployed
# 0         01         001         01001  Autauga County, AL                 3.6
# 1         01         003         01003  Baldwin County, AL                 3.6
# 2         01         005         01005  Barbour County, AL                 5.2
# 3         01         007         01007     Bibb County, AL                 4.0
# 4         01         009         01009   Blount County, AL                 3.5

# %% [markdown]
# Load up the county map

# %%
counties = gpd.read_file(
    "../data/counties/",
    dtype = {
       "GEOID": "object" 
    }
)

counties.head()
# Out:
#    GEOID       NAME          NAMELSAD  \
# 0  31039     Cuming     Cuming County
# 1  53069  Wahkiakum  Wahkiakum County
# 2  35011    De Baca    De Baca County
# 3  31109  Lancaster  Lancaster County
# 4  31129   Nuckolls   Nuckolls County
#
#                                             geometry
# 0  POLYGON ((246290.041 -328619.667, 246286.510 -...
# 1  POLYGON ((-1770686.984 398793.664, -1771124.91...
# 2  POLYGON ((-422754.447 -1210188.449, -422784.93...
# 3  POLYGON ((260193.977 -463717.021, 260172.000 -...
# 4  POLYGON ((146978.459 -544334.301, 146978.432 -...

# %% [markdown]
# Merge

# %%
merged = counties.merge(
    df,
    left_on = "GEOID",
    right_on = "combined_fips"
)

merged.head()
# Out:
#    GEOID       NAME          NAMELSAD  \
# 0  31039     Cuming     Cuming County
# 1  53069  Wahkiakum  Wahkiakum County
# 2  35011    De Baca    De Baca County
# 3  31109  Lancaster  Lancaster County
# 4  31129   Nuckolls   Nuckolls County
#
#                                             geometry state_fips county_fips  \
# 0  POLYGON ((246290.041 -328619.667, 246286.510 -...         31         039
# 1  POLYGON ((-1770686.984 398793.664, -1771124.91...         53         069
# 2  POLYGON ((-422754.447 -1210188.449, -422784.93...         35         011
# 3  POLYGON ((260193.977 -463717.021, 260172.000 -...         31         109
# 4  POLYGON ((146978.459 -544334.301, 146978.432 -...         31         129
#
#   combined_fips                  name  percent_unemployed
# 0         31039     Cuming County, NE                 2.5
# 1         53069  Wahkiakum County, WA                 6.5
# 2         35011    De Baca County, NM                 4.6
# 3         31109  Lancaster County, NE                 2.5
# 4         31129   Nuckolls County, NE                 2.6

# %% [markdown]
# Now plot!

# %%
ax = merged.plot(
    column = "percent_unemployed",
    figsize = (16,9),
    cmap = "Greens",
    vmin = 0,
    vmax = 20,
    linewidth = 0.2,
    edgecolor = "lightgray",
    legend = True
)

ax.axis("off")

ax.set_title("2018 Unemployment", fontsize = 24)
# Out:
# Text(0.5, 1.0, '2018 Unemployment')

# %% [markdown]
# Save it as a file

# %%
ax.get_figure().savefig("../output/unemployment.png")
