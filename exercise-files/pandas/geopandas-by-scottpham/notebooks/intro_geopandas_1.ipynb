# %% [markdown]
# A walkthrough of some of the cool things you can do in GeoPandas and why

# %% [markdown]
# First, import the library. Imports always go at the top of the project

# %%
import geopandas as gpd
import pandas as pd

# %% [markdown]
# Next, we write what's called a _magic command_. That's a piece of code that tells Jupyter to do something differently. Magic commands are always preceded with the `%` sign.
#
# `%COMMAND ARGUMENT1, ARGUMENT2...`
#
# In this case, we're simply going to tell Jupyter to display graphics "inline" as we make them. If we don't do that, then we won't be able to see the graphics without exporing them to a file, which is tedious if you're making lots of graphics or trying to iterate over a single one unti it's perfect.

# %%
# %matplotlib inline

# %% [markdown]
# GeoPandas works a lot like pandas. Reading a file is simple. Where in Pandas you used the `pd.read_csv()` method, here we use the `gpd.read_file` method.

# %%
states = gpd.read_file("../data/states")

# %% [markdown]
# Note that above I didn't write the name of the file like `../folder/filename.something`. That's because we're dealing with a [shapefile](https://en.wikipedia.org/wiki/Shapefile) which is really a folder with a bunch of files, rather than a single file. When reading a in a shapefile, you can just refer to the folder and GeoPandas will figure it out.

# %% [markdown]
# You can do `GeoDataFrame.head()` and it works a lot like `DataFrame.head()`.

# %%
states.head()
# Out:
#   GEOID STUSPS           NAME  \
# 0    54     WV  West Virginia
# 1    12     FL        Florida
# 2    17     IL       Illinois
# 3    27     MN      Minnesota
# 4    24     MD       Maryland
#
#                                             geometry
# 0  POLYGON ((1561571.961498005 -483477.9709532264...
# 1  (POLYGON ((1300534.537687921 -1450505.84259490...
# 2  POLYGON ((742564.4861695889 -445238.1828612213...
# 3  POLYGON ((245479.8020581223 186204.4565480486,...
# 4  POLYGON ((1914704.978465645 -379436.5462723099...

# %% [markdown]
# The `geomoetry` column is the most important. All GeoDataFrames have `geometry` columns. This column can contain `Point` data--like the locations of cities or specific addresses, or `Polygon` data. In this case, we have polygons. Let's take a look with the handy `DataFrame.plot()` method.

# %%
states.plot()

# %% [markdown]
# Cool! Note that we can do a lot of things to make this look better. A lot of the aesthetics can be set right inside of the `plot` function. Others have to be set after you build the initial plot.
#
# By convention, we call the map object an `Axes` object. (Pronounced AXE-eez). It doesn't refer to the lines in a chart that mark the scale. It's a [Matplotlib concept](https://matplotlib.org/api/axes_api.html).
#
# I won't go into what all these options mean, but check out the documention on how to plot at [the GeoPandas documentation site](http://geopandas.org/mapping.html).

# %%
ax = states.plot(
    # the size of the plot in inches
    figsize = (16,9),
    # most CSS colors will work here
    color = "steelblue",
    # line color
    edgecolor = "white",
    linewidth = 0.5
)

ax.axis("off")
ax.set_title(
    "What a nice lookin' map",
    fontsize = 35
)
# Out:
# Text(0.5, 1.0, "What a nice lookin' map")

# %% [markdown]
# Let's do it again with a counties map. You'll see how it's basically the same operation.

# %%
counties = gpd.read_file("../data/counties/")

counties.head()
# Out:
#    GEOID       NAME          NAMELSAD  \
# 0  31039     Cuming     Cuming County
# 1  53069  Wahkiakum  Wahkiakum County
# 2  35011    De Baca    De Baca County
# 3  31109  Lancaster  Lancaster County
# 4  31129   Nuckolls   Nuckolls County
#
#                                             geometry
# 0  POLYGON ((246290.0411551894 -328619.667039162,...
# 1  POLYGON ((-1770686.983550074 398793.6640856052...
# 2  POLYGON ((-422754.4474200015 -1210188.44889264...
# 3  POLYGON ((260193.976508197 -463717.0213689978,...
# 4  POLYGON ((146978.4586902861 -544334.3005906644...

# %%
# read in the file and go straight to plotting!
ax = counties.plot(
    figsize = (16,9),
    color = "steelblue",
    # line color
    edgecolor = "white",
    linewidth = 0.5
)

ax.axis("off")

ax.set_title(
    "U.S. Counties",
    fontsize = 30
);

# %% [markdown]
# **Making thematic maps with your merging powers**

# %% [markdown]
# I have a CSV of bigfoot sightings from the "official" [Geographic Database of Bigfood/Sasquatch Sightings and Reports](https://www.bfro.net/GDB/)

# %%
bigfoot = pd.read_csv("../data/bigfoot.csv")

# %% [markdown]
# Note that I use Pandas to open this file because it's not a GeoDataFrame...yet

# %%
bigfoot.head(1)
# Out:
#      state  sightings
# 0  Montana         47

# %% [markdown]
# To make it a GeoDataFrame, we'll need to merge the bigfoot data with one of our shapefiles. We'll use the state shapefile from above because we can use the state name as a key. Take a look at it again:

# %%
states.head(1)
# Out:
#   GEOID STUSPS           NAME  \
# 0    54     WV  West Virginia
#
#                                             geometry
# 0  POLYGON ((1561571.961498005 -483477.9709532264...

# %%
bigfoot_geo = states.merge(
    bigfoot,
    left_on = "NAME",
    right_on = "state"
)

bigfoot_geo
# Out:
#    GEOID STUSPS            NAME  \
# 0     54     WV   West Virginia
# 1     12     FL         Florida
# 2     17     IL        Illinois
# 3     27     MN       Minnesota
# 4     24     MD        Maryland
# 5     44     RI    Rhode Island
# 6     16     ID           Idaho
# 7     33     NH   New Hampshire
# 8     37     NC  North Carolina
# 9     50     VT         Vermont
# 10    09     CT     Connecticut
# 11    10     DE        Delaware
# 12    35     NM      New Mexico
# 13    06     CA      California
# 14    34     NJ      New Jersey
# 15    55     WI       Wisconsin
# 16    41     OR          Oregon
# 17    31     NE        Nebraska
# 18    42     PA    Pennsylvania
# 19    53     WA      Washington
# 20    22     LA       Louisiana
# 21    13     GA         Georgia
# 22    01     AL         Alabama
# 23    49     UT            Utah
# 24    39     OH            Ohio
# 25    48     TX           Texas
# 26    08     CO        Colorado
# 27    45     SC  South Carolina
# 28    40     OK        Oklahoma
# 29    47     TN       Tennessee
# 30    56     WY         Wyoming
# 31    38     ND    North Dakota
# 32    21     KY        Kentucky
# 33    23     ME           Maine
# 34    36     NY        New York
# 35    32     NV          Nevada
# 36    26     MI        Michigan
# 37    05     AR        Arkansas
# 38    28     MS     Mississippi
# 39    29     MO        Missouri
# 40    30     MT         Montana
# 41    20     KS          Kansas
# 42    18     IN         Indiana
# 43    46     SD    South Dakota
# 44    25     MA   Massachusetts
# 45    51     VA        Virginia
# 46    19     IA            Iowa
# 47    04     AZ         Arizona
#
#                                              geometry           state  \
# 0   POLYGON ((1561571.961498005 -483477.9709532264...   West Virginia
# 1   (POLYGON ((1300534.537687921 -1450505.84259490...         Florida
# 2   POLYGON ((742564.4861695889 -445238.1828612213...        Illinois
# 3   POLYGON ((245479.8020581223 186204.4565480486,...       Minnesota
# 4   POLYGON ((1914704.978465645 -379436.5462723099...        Maryland
# 5   (POLYGON ((2284754.209981316 36016.0881289286,...    Rhode Island
# 6   POLYGON ((-1320390.644256198 120880.5521476415...           Idaho
# 7   POLYGON ((2174741.053755225 220735.6691784294,...   New Hampshire
# 8   POLYGON ((1570933.07717931 -826582.7352000197,...  North Carolina
# 9   POLYGON ((2077303.749474204 265450.63257462, 2...         Vermont
# 10  POLYGON ((2153209.082682581 -17580.64434525757...     Connecticut
# 11  POLYGON ((2051669.129315703 -330166.8793766249...        Delaware
# 12  POLYGON ((-534160.6056557392 -870239.335965946...      New Mexico
# 13  (POLYGON ((-1976210.176751327 -98944.189742802...      California
# 14  POLYGON ((2057259.260527866 -176271.9332921049...      New Jersey
# 15  POLYGON ((552058.1734626418 95955.669354189, 5...       Wisconsin
# 16  POLYGON ((-1831536.295206724 364072.6731111621...          Oregon
# 17  POLYGON ((-334822.2808841341 -325088.606710592...        Nebraska
# 18  POLYGON ((1595331.800639666 -159299.258397745,...    Pennsylvania
# 19  POLYGON ((-1690283.280441956 614580.0237173932...      Washington
# 20  POLYGON ((742294.6323411128 -1296525.291223537...       Louisiana
# 21  POLYGON ((1346866.157033475 -1115974.110833468...         Georgia
# 22  POLYGON ((1085909.68386363 -1080750.826530671,...         Alabama
# 23  POLYGON ((-1192232.476556125 -464681.144059318...            Utah
# 24  POLYGON ((1267318.330253894 -328422.2004155985...            Ohio
# 25  POLYGON ((-377587.5832193523 -1433672.04329427...           Texas
# 26  POLYGON ((-767208.3540634887 -489021.382853692...        Colorado
# 27  POLYGON ((1580530.105711904 -1036244.408023603...  South Carolina
# 28  POLYGON ((-337.1933846907922 -944306.674136692...        Oklahoma
# 29  POLYGON ((1586201.99391063 -813711.6279078639,...       Tennessee
# 30  POLYGON ((-890268.378043708 -126860.2331516778...         Wyoming
# 31  POLYGON ((-304779.7529252027 266769.1151093661...    North Dakota
# 32  (POLYGON ((1050958.702280803 -757618.211598819...        Kentucky
# 33  POLYGON ((2267095.829355157 278234.6291265127,...           Maine
# 34  (POLYGON ((1668826.84669574 -43997.15490607957...        New York
# 35  POLYGON ((-1579160.106525039 -146615.867748462...          Nevada
# 36  POLYGON ((1052056.750469954 124527.0137370408,...        Michigan
# 37  POLYGON ((490500.0958097461 -972532.5730718165...        Arkansas
# 38  POLYGON ((834371.5168100002 -1163532.10657909,...     Mississippi
# 39  POLYGON ((467218.9946418963 -668691.7166475024...        Missouri
# 40  POLYGON ((-1165498.211977536 390033.128975421,...         Montana
# 41  POLYGON ((-177735.9553963572 -698263.421789290...          Kansas
# 42  POLYGON ((1050878.734756391 -423217.2883193014...         Indiana
# 43  POLYGON ((-38612.90331293085 105047.6653269784...    South Dakota
# 44  POLYGON ((2296293.623161351 75361.32650998856,...   Massachusetts
# 45  POLYGON ((1930086.072448505 -394000.8112975492...        Virginia
# 46  POLYGON ((286711.2838217468 -265048.7033267946...            Iowa
# 47  POLYGON ((-1352715.71733633 -1213425.984737277...         Arizona
#
#     sightings
# 0         102
# 1         325
# 2         298
# 3          73
# 4          35
# 5           5
# 6          87
# 7          16
# 8          97
# 9           9
# 10         16
# 11          5
# 12         42
# 13        441
# 14         70
# 15         99
# 16        250
# 17         15
# 18        117
# 19        663
# 20         43
# 21        132
# 22         98
# 23         70
# 24        290
# 25        237
# 26        124
# 27         52
# 28         98
# 29         99
# 30         28
# 31          6
# 32        113
# 33         17
# 34        108
# 35          9
# 36        218
# 37        103
# 38         23
# 39        147
# 40         47
# 41         46
# 42         78
# 43         17
# 44         35
# 45         78
# 46         76
# 47         84

# %%
bigfoot_geo.plot(
    column = "sightings",
    legend = True
)

# %% [markdown]
# Nice! But the color scheme is just awful. Let's use the [colormaps](https://matplotlib.org/users/colormaps.html) from matplotlib.

# %%
ax = bigfoot_geo.plot(
    legend = True,
    column = "sightings",
    cmap = "Purples",
    edgecolor = "darkgray",
    linewidth = 0.5,
    figsize = (16,9)
)

ax.axis("off")

ax.set_title(
    "Bigfoot sightings",
    fontsize = 30
)
# Out:
# Text(0.5, 1.0, 'Bigfoot sightings')

# %% [markdown]
# Want to save it as a file? It's a bit of an odd process but it's not hard.

# %%
# first, get the "Figure" from the plot object.
fig = ax.get_figure()

# then, use the savefig method on that Figure object
fig.savefig("../output/bigfoot.png")
