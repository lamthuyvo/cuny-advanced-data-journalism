# %%
import requests
import json
import csv

# %%
api_key = open('../data/youtube-api-key.txt').read().strip()
api_url = 'https://www.googleapis.com/youtube/v3/search?key='+api_key+'&part=snippet&channelId=UCJFp8uSYCjXOMnkUyb3CQ3Q'

# %%
# this opens the link and tells your computer that the format it is reading is JSON
api_response = requests.get(api_url).text
videos = json.loads(api_response)

# %%
print(requests.get(api_url))
print(api_response)
# Out:
# <Response [200]>
# {
#  "kind": "youtube#searchListResponse",
#  "etag": "\"XI7nbFXulYBIpL0ayR_gDh3eu1k/ubefoe0_hzo8Bfq840_hI9a-7Eg\"",
#  "nextPageToken": "CAUQAA",
#  "regionCode": "US",
#  "pageInfo": {
#   "totalResults": 5408,
#   "resultsPerPage": 5
#  },
#  "items": [
#   {
#    "kind": "youtube#searchResult",
#    "etag": "\"XI7nbFXulYBIpL0ayR_gDh3eu1k/SCNlZxTPnx9vUSIjSpCQpj_luO4\"",
#    "id": {
#     "kind": "youtube#video",
#     "videoId": "5Sa9nYKiYg0"
#    },
#    "snippet": {
#     "publishedAt": "2018-02-28T17:00:42.000Z",
#     "channelId": "UCJFp8uSYCjXOMnkUyb3CQ3Q",
#     "title": "The Original Orange Chicken by Panda Express",
#     "description": "Reserve the One Top: http://bit.ly/2v0iast Get the recipe: https://tasty.co/recipe/original-orange-chicken-by-panda-express Buy the Tasty Cookbook Today: ...",
#     "thumbnails": {
#      "default": {
#       "url": "https://i.ytimg.com/vi/5Sa9nYKiYg0/default.jpg",
#       "width": 120,
#       "height": 90
#      },
#      "medium": {
#       "url": "https://i.ytimg.com/vi/5Sa9nYKiYg0/mqdefault.jpg",
#       "width": 320,
#       "height": 180
#      },
#      "high": {
#       "url": "https://i.ytimg.com/vi/5Sa9nYKiYg0/hqdefault.jpg",
#       "width": 480,
#       "height": 360
#      }
#     },
#     "channelTitle": "Tasty",
#     "liveBroadcastContent": "none"
#    }
#   },
#   {
#    "kind": "youtube#searchResult",
#    "etag": "\"XI7nbFXulYBIpL0ayR_gDh3eu1k/mp8c_xIFDUztCjBguQpu1KEiYeU\"",
#    "id": {
#     "kind": "youtube#video",
#     "videoId": "3vUtRRZG0xY"
#    },
#    "snippet": {
#     "publishedAt": "2017-06-14T16:00:09.000Z",
#     "channelId": "UCJFp8uSYCjXOMnkUyb3CQ3Q",
#     "title": "The Best Chewy Chocolate Chip Cookies",
#     "description": "Check out the Tasty One-Stop Shop for cookbooks, aprons, hats, and more at TastyShop.com: http://bit.ly/2mEBY0e Super soft, chewy, and studded with ...",
#     "thumbnails": {
#      "default": {
#       "url": "https://i.ytimg.com/vi/3vUtRRZG0xY/default.jpg",
#       "width": 120,
#       "height": 90
#      },
#      "medium": {
#       "url": "https://i.ytimg.com/vi/3vUtRRZG0xY/mqdefault.jpg",
#       "width": 320,
#       "height": 180
#      },
#      "high": {
#       "url": "https://i.ytimg.com/vi/3vUtRRZG0xY/hqdefault.jpg",
#       "width": 480,
#       "height": 360
#      }
#     },
#     "channelTitle": "Tasty",
#     "liveBroadcastContent": "none"
#    }
#   },
#   {
#    "kind": "youtube#searchResult",
#    "etag": "\"XI7nbFXulYBIpL0ayR_gDh3eu1k/M_Y8cgSo-yIDCRoVptE_ZuYO0FA\"",
#    "id": {
#     "kind": "youtube#video",
#     "videoId": "KLGSLCaksdY"
#    },
#    "snippet": {
#     "publishedAt": "2016-10-27T01:00:00.000Z",
#     "channelId": "UCJFp8uSYCjXOMnkUyb3CQ3Q",
#     "title": "How To Cook With Cast Iron",
#     "description": "This guide will make cooking with cast iron a breeze! Check us out on Facebook! - facebook.com/buzzfeedtasty MUSIC Promenade En Provence Licensed via ...",
#     "thumbnails": {
#      "default": {
#       "url": "https://i.ytimg.com/vi/KLGSLCaksdY/default.jpg",
#       "width": 120,
#       "height": 90
#      },
#      "medium": {
#       "url": "https://i.ytimg.com/vi/KLGSLCaksdY/mqdefault.jpg",
#       "width": 320,
#       "height": 180
#      },
#      "high": {
#       "url": "https://i.ytimg.com/vi/KLGSLCaksdY/hqdefault.jpg",
#       "width": 480,
#       "height": 360
#      }
#     },
#     "channelTitle": "Tasty",
#     "liveBroadcastContent": "none"
#    }
#   },
#   {
#    "kind": "youtube#searchResult",
#    "etag": "\"XI7nbFXulYBIpL0ayR_gDh3eu1k/wJyYr1kgLk0ihxN-ZXbVStmhtK8\"",
#    "id": {
#     "kind": "youtube#video",
#     "videoId": "TeoS_fQWvkY"
#    },
#    "snippet": {
#     "publishedAt": "2017-02-02T17:00:23.000Z",
#     "channelId": "UCJFp8uSYCjXOMnkUyb3CQ3Q",
#     "title": "Jiggly Fluffy Japanese Cheesecake",
#     "description": "Customize & buy the Tasty Cookbook here: http://bzfd.it/2fpfeu5 Here is what you'll need! Fluffy Jiggly Japanese Cheesecake Servings: 6-8 INGREDIENTS ⅔ ...",
#     "thumbnails": {
#      "default": {
#       "url": "https://i.ytimg.com/vi/TeoS_fQWvkY/default.jpg",
#       "width": 120,
#       "height": 90
#      },
#      "medium": {
#       "url": "https://i.ytimg.com/vi/TeoS_fQWvkY/mqdefault.jpg",
#       "width": 320,
#       "height": 180
#      },
#      "high": {
#       "url": "https://i.ytimg.com/vi/TeoS_fQWvkY/hqdefault.jpg",
#       "width": 480,
#       "height": 360
#      }
#     },
#     "channelTitle": "Tasty",
#     "liveBroadcastContent": "none"
#    }
#   },
#   {
#    "kind": "youtube#searchResult",
#    "etag": "\"XI7nbFXulYBIpL0ayR_gDh3eu1k/OsRgqHeccKKt6CGBkBUev29-q6o\"",
#    "id": {
#     "kind": "youtube#video",
#     "videoId": "3_Pp9fwLkBY"
#    },
#    "snippet": {
#     "publishedAt": "2016-05-31T18:00:00.000Z",
#     "channelId": "UCJFp8uSYCjXOMnkUyb3CQ3Q",
#     "title": "Puff Pastry 4 Ways",
#     "description": "Here is what you'll need! RECIPE: Cream Cheese Filling INGREDIENTS 1 8-ounce block cream cheese ¼ cup granulated sugar ½ teaspoon vanilla extract ...",
#     "thumbnails": {
#      "default": {
#       "url": "https://i.ytimg.com/vi/3_Pp9fwLkBY/default.jpg",
#       "width": 120,
#       "height": 90
#      },
#      "medium": {
#       "url": "https://i.ytimg.com/vi/3_Pp9fwLkBY/mqdefault.jpg",
#       "width": 320,
#       "height": 180
#      },
#      "high": {
#       "url": "https://i.ytimg.com/vi/3_Pp9fwLkBY/hqdefault.jpg",
#       "width": 480,
#       "height": 360
#      }
#     },
#     "channelTitle": "Tasty",
#     "liveBroadcastContent": "none"
#    }
#   }
#  ]
# }

# %%
# here's how the CSV library works: To create and upen up a csv file you need to do this:
with open('../output/youtube_videos.csv', 'w+') as csv_file:
   
    # use the csv function that we imported to write a new csv file
    csv_writer = csv.writer(csv_file)
    # write the first row of your CSV
    csv_writer.writerow(['video_id', 'description', 'created_time', 'link'])

# %%
# here's how the CSV library works: To create and upen up a csv file you need to do this:
with open('../output/youtube_videos.csv', 'w+') as csv_file:
    # use the csv function that we imported to write a new csv file
    csv_writer = csv.writer(csv_file)
    # write the first row of your CSV
    csv_writer.writerow(['publishedAt','title','description','thumbnailurl'])
    # define what kind of information from the API we want in each row
    
    # this is a loop, which means it takes each item in the entire json data set and cycles through it, each time print the message of the post in your console
    for video in videos['items']:
        print(video['snippet']['publishedAt'], video['snippet']['title'], video['snippet']['description'], video['snippet']['thumbnails']['default']['url'])
        video_data_row  = [video['snippet']['publishedAt'], video['snippet']['title'], video['snippet']['description'], video['snippet']['thumbnails']['default']['url']]
        csv_writer.writerow(video_data_row)
# Out:
# 5Sa9nYKiYg0 The Original Orange Chicken by Panda Express Reserve the One Top: http://bit.ly/2v0iast Get the recipe: https://tasty.co/recipe/original-orange-chicken-by-panda-express Buy the Tasty Cookbook Today: ... 2018-02-28T17:00:42.000Z
# 3vUtRRZG0xY The Best Chewy Chocolate Chip Cookies Check out the Tasty One-Stop Shop for cookbooks, aprons, hats, and more at TastyShop.com: http://bit.ly/2mEBY0e Super soft, chewy, and studded with ... 2017-06-14T16:00:09.000Z
# KLGSLCaksdY How To Cook With Cast Iron This guide will make cooking with cast iron a breeze! Check us out on Facebook! - facebook.com/buzzfeedtasty MUSIC Promenade En Provence Licensed via ... 2016-10-27T01:00:00.000Z
# TeoS_fQWvkY Jiggly Fluffy Japanese Cheesecake Customize & buy the Tasty Cookbook here: http://bzfd.it/2fpfeu5 Here is what you'll need! Fluffy Jiggly Japanese Cheesecake Servings: 6-8 INGREDIENTS ⅔ ... 2017-02-02T17:00:23.000Z
# 3_Pp9fwLkBY Puff Pastry 4 Ways Here is what you'll need! RECIPE: Cream Cheese Filling INGREDIENTS 1 8-ounce block cream cheese ¼ cup granulated sugar ½ teaspoon vanilla extract ... 2016-05-31T18:00:00.000Z

# %%
# here's how the CSV library works: To create and upen up a csv file you need to do this:
with open('../output/youtube_videos.csv', 'w+') as csv_file:
    # use the csv function that we imported to write a new csv file
    csv_writer = csv.writer(csv_file)
    # write the first row of your CSV
    csv_writer.writerow(['publishedAt','title','description','thumbnailurl'])
    # define what kind of information from the API we want in each row
    has_another_page = True
    while has_another_page:
        for video in videos['items']:
            video_data_row  = [ video['snippet']['publishedAt'], video['snippet']['title'], video['snippet']['description'], video['snippet']['thumbnails']['default']['url']]
            csv_writer.writerow(video_data_row)
        if 'nextPageToken' in videos.keys():
            next_page_url = api_url + "&pageToken=" +videos['nextPageToken']
            next_page_posts = requests.get(next_page_url)
            videos = json.loads(next_page_posts.text)
        else:
            print('no more videos!')
            has_another_page = False
# Out:
#   File "<tokenize>", line 4
#     print(video['id']['videoId'])
#     ^
# IndentationError: unindent does not match any outer indentation level
